# %% [markdown]
# <a href="https://colab.research.google.com/github/ingjosepavel-pixel/Mi_primer_repositorio/blob/main/Practica_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Universidad Tec Milenio
# ##Jose Pavel Hernandez Cruz
# ###Actividad 4

# %%
# Hola mundo
print("Hola mundo")
# Out:
# Hola mundo

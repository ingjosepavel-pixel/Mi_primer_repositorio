# %% [markdown]
# <a href="https://colab.research.google.com/github/ingjosepavel-pixel/Mi_primer_repositorio/blob/Mi_primera_rama/Practica_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Universidad Tec Milenio
# ##Jose Pavel Hernandez Cruz
# ###Actividad 4

# %%
# Hola mundo
print("Hola mundo")
# Out:
# Hola mundo

# %%
#calculadora simple
a=int(input("Ingrese el primer numero"))
b=int(input("ingrese el segundo nuemro"))
print("suma: ",a+b)
# Out:
# Ingrese el primer numero8
# ingrese el segundo nuemro3
# suma:  11

# %%
print("Quiero aprender GIT")
# Out:
# Quiero aprender GIT

# %%
Luis = 5
Maria = 10
Pedro = 8
Jose = 9
Jorge = 7
promedio = (Luis + Maria + Pedro + Jose + Jorge) / 5
__builtins__.print(promedio)
# Out:
# 7.8
